# %%
#discrete random variable of rolling a dice
#PMF
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
die=stats.randint(1,7)
r=range(1,7)
prob=[die.pmf(i) for i in r]

prob1=die.pmf(r)

sample=np.random.randint(1,7,size=30)
plt.hist(sample,bins=30)

plt.style.use("seaborn-colorblind")
plt.bar(r,prob)
# Out:
# <BarContainer object of 6 artists>

# %%
#continous random variable
#PDF
import matplotlib.pyplot as plt
from numpy.random import uniform
uniform(low=-2,high=2,size=30)
s=uniform(low=-2,high=2,size=30)

plt.hist(s,density=True)
# Out:
# (array([0.25374521, 0.25374521, 0.16916347, 0.08458174, 0.42290868,
#         0.25374521, 0.08458174, 0.50749042, 0.16916347, 0.33832695]),
#  array([-1.95906185, -1.56496574, -1.17086963, -0.77677352, -0.38267741,
#          0.0114187 ,  0.40551481,  0.79961092,  1.19370703,  1.58780314,
#          1.98189924]),
#  <BarContainer object of 10 artists>)
